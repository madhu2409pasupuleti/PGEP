# %% [markdown]
# # Class 1 - Python Basics

# %%
# .ipynb - IPython Notebook - Jupyter or Colab
# .py - Python - Notepad

# %%
studentname = '123.5'

# %%
type(studentname)
# Out:
# str

# %%
studentname = Rahul

# %%
Rahul = "Tiwari"

# %%
studentname
# Out:
# 'Tiwari'

# %%
name="Rahul"
NAME="Rohit"

# %%
name
# Out:
# 'Rahul'

# %%
NAME
# Out:
# 'Rohit'

# %%
# Naming Convention 
    #1. Alphabets - Cap | Small - Start, Middle, end 
    #2. Underscore _ - At the start, Middle, End 
    #3. Numbers - Numbers cannot be at the start
    #4. 35 Python keywords - We cannot use as variable name
    #5. PI =3.14

# %%
stu_name = ""
stuname_ = ""
_stuname = ""

# %%
n1ame1 = "Rahul"

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
For = "RAhul"

# %%
For
# Out:
# 'RAhul'

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
edu = bool(input("Enter your Grad status: "))
marks = float(input("Enter your marks: "))
print(type(name))
print(type(age))
print(type(edu))
print(type(marks))
# Out:
# Enter your name:  rahul
# Enter your age:  40
# Enter your Grad status:  0
# Enter your marks:  44
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %%
edu
# Out:
# True

# %%
print("Hi",end="")
print("Hello",end="")
print("How are you?")
# Out:
# HiHelloHow are you?

# %%
print("Hi","Hello","How are you?")
# Out:
# Hi Hello How are you?

# %%
name = "Rahul"
company = "Deloitte"
salary = 10000
location = "Gurgaon"

print("Hi",name,"your comapny is", company, "your salary is", salary, "your location is", location)
# Out:
# Hi Rahul your comapny is Deloitte your salary is 10000 your location is Gurgaon

# %%
print(f"Hi {name}, your comapny is {company} your salary is {salary} your location is {location}")
# Out:
# Hi Rahul, your comapny is Deloitte your salary is 10000 your location is Gurgaon

# %%
num1 = 10
num2 = 2
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
print(num1//num2)
print(num1%num2)
print(num1**num2)
# Out:
# 12
# 8
# 20
# 5.0
# 5
# 0
# 100

# %%
int("1")+int("2")
# Out:
# 3

# %%
num1 = 10
num2 = 3
print(num1>num2)
print(num1>=num2)
print(num1<num2)
print(num1<=num2)
print(num1==num2)
print(num1!=num2)
# Out:
# True
# True
# False
# False
# False
# True

# %%
num1=num2

# %%
num1
# Out:
# 3

# %%
a = 10 
a = a + 20
a
# Out:
# 30

# %%
a = 10
a+=20
a
# Out:
# 30

# %%
not((10>3) or (3<1))
# Out:
# False

# %%
T and T = T
T and F = F
F and T = F
F and F = F

# %%
T or T = T
T or F = T
F or T = T
F or F = F

# %%
not(True)
# Out:
# False

# %%
# Special Operators 
    # Membership 
        # in , not in 
    # Identity
        # is  is not

# %%
"r"  in "Rahul"
# Out:
# False

# %%
"z" in ["A","B","C"]
# Out:
# False

# %%
"25" in "25"
# Out:
# True

# %%
a = 1000
b = 1000
print(id(a))
print(id(b))
a is b
# Out:
# 2524144661936
# 2524144661968
# False

# %%
a=b=1000
print(id(a))
print(id(b))
a is b
# Out:
# 2524144659792
# 2524144659792
# True

# %% [markdown]
# # End
